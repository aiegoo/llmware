# %% [markdown]
# "<br>
# #                   *** FAST START to create vector embeddings from documents ***<br>
# #<br>
# #   docs2vecs_with_milvus-contracts - parses, text chunks and embeds legal contracts<br>
# #   the sample documents (~80 legal template contracts) can be pulled down from a public S3 repo with the command:<br>
# #           sample_files_path = Setup().load_sample_files()<br>
# #   note:  this example requires Milvus + MongoDB - please see the README instructions to install<br>

# %%
import os
from llmware.library import Library
from llmware.retrieval import Query
from llmware.setup import Setup
from llmware.status import Status

# %%
def parse_and_generate_vector_embeddings(library_name):

    # Step 0 - Configuration - we will use these in Step 4 to install the embeddings
    embedding_model = "industry-bert-contracts"
    vector_db = "milvus"

    # Step 1 - Create library which is the main 'organizing construct' in llmware
    print ("\nupdate: Step 1 - Creating library: {}".format(library_name))
    library = Library().create_new_library(library_name)

    # Step 2 - Pull down the sample files from S3 through the .load_sample_files() command
    #   --note: if you need to refresh the sample files, set 'over_write=True'
    print ("update: Step 2 - Downloading Sample Files")
    sample_files_path = Setup().load_sample_files(over_write=False)

    # Step 3 - point ".add_files" method to the folder of documents that was just created
    #   this method parses all of the documents, text chunks, and captures in MongoDB
    print("update: Step 3 - Parsing and Text Indexing Files")
    library.add_files(input_folder_path=os.path.join(sample_files_path, "AgreementsLarge"))

    # Step 4 - Install the embeddings
    print("\nupdate: Step 4 - Generating Embeddings in {} db - with Model- {}".format(vector_db, embedding_model))
    library.install_new_embedding(embedding_model_name=embedding_model, vector_db=vector_db)

    # note: for using llmware as part of a larger application, you can check the real-time status by polling Status()
    #   --both the EmbeddingHandler and Parsers write to Status() at intervals while processing
    update = Status().get_embedding_status(library_name, embedding_model)
    print("update: Embeddings Complete - Status() check at end of embedding - ", update)

    # Step 5 - start using the new vector embeddings with Query
    sample_query = "incentive compensation"
    print("\n\nupdate: Step 5 - Query: {}".format(sample_query))
    query_results = Query(library).semantic_query(sample_query, result_count=20)
    for i, entries in enumerate(query_results):

        # each query result is a dictionary with many useful keys
        text = entries["text"]
        document_source = entries["file_source"]
        page_num = entries["page_num"]
        vector_distance = entries["distance"]

        #  for display purposes only, we will only show the first 100 characters of the text
        if len(text) > 125:  text = text[0:125] + " ... "
        print("\nupdate: query results - {} - document - {} - page num - {} - distance - {} "
              .format( i, document_source, page_num, vector_distance))
        print("update: text sample - ", text)

# %%
if __name__ == "__main__":

    # pick any name for the library
    user_selected_name = "contracts"
    parse_and_generate_vector_embeddings(user_selected_name)
# Out:
# update: Step 1 - Creating library: contracts
# /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/collection.py:1685: UserWarning: use an explicit session with no_cursor_timeout=True otherwise the cursor may still timeout after 30 minutes, for more info see https://mongodb.com/docs/v4.4/reference/method/cursor.noCursorTimeout/#session-idle-timeout-overrides-nocursortimeout
#   return Cursor(self, *args, **kwargs)
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# Cell In[3], line 5
#       1 if __name__ == "__main__":
#       2
#       3     # pick any name for the library
#       4     user_selected_name = "contracts"
# ----> 5     parse_and_generate_vector_embeddings(user_selected_name)
#
# Cell In[2], line 9, in parse_and_generate_vector_embeddings(library_name)
#       7 # Step 1 - Create library which is the main 'organizing construct' in llmware
#       8 print ("\nupdate: Step 1 - Creating library: {}".format(library_name))
# ----> 9 library = Library().create_new_library(library_name)
#      11 # Step 2 - Pull down the sample files from S3 through the .load_sample_files() command
#      12 #   --note: if you need to refresh the sample files, set 'over_write=True'
#      13 print ("update: Step 2 - Downloading Sample Files")
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/llmware/library.py:145, in Library.create_new_library(self, library_name, account_name)
#     142 # apply safety check to library_name path
#     143 library_name = Utilities().secure_filename(library_name)
# --> 145 library_exists = self.check_if_library_exists(library_name,account_name)
#     147 if library_exists:
#     148     # do not create
#     149     logging.info("update: library already exists - returning library - %s - %s ", library_name, account_name)
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/llmware/library.py:302, in Library.check_if_library_exists(self, library_name, account_name)
#     299 """ Check if library exists by library string name """
#     301 # first look in library catalog
# --> 302 library_card = LibraryCatalog().get_library_card(library_name, account_name=account_name)
#     304 # check file path
#     305 lib_path = os.path.join(LLMWareConfig.get_library_path(), account_name, library_name)
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/llmware/library.py:838, in LibraryCatalog.get_library_card(self, library_name, account_name)
#     834 """ Gets the selected library card for the selected library_name """
#     836 # note: will return either library_card {} or None
# --> 838 db_record = CollectionRetrieval("library", account_name=account_name).lookup("library_name", library_name)
#     840 if isinstance(db_record, list):
#     841     if len(db_record) > 0:
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/llmware/resources.py:111, in CollectionRetrieval.lookup(self, key, value)
#     109 def lookup(self, key,value):
#     110     """lookup returns a list of dictionary entries - generally a list of 1 entry for 'lookup'"""
# --> 111     return self._retriever.lookup(key,value)
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/llmware/resources.py:631, in MongoRetrieval.lookup(self, key, value)
#     628         logging.info("update: mongo lookup - could not find _id into ObjectID - %s", value)
#     629         value = value
# --> 631 target = list(self.collection.find({key:value}, no_cursor_timeout=True))
#     633 return target
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/cursor.py:1243, in Cursor.next(self)
#    1241 if self.__empty:
#    1242     raise StopIteration
# -> 1243 if len(self.__data) or self._refresh():
#    1244     return self.__data.popleft()
#    1245 else:
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/cursor.py:1160, in Cursor._refresh(self)
#    1138         raise InvalidOperation(
#    1139             "Passing a 'hint' is required when using the min/max query"
#    1140             " option to ensure the query utilizes the correct index"
#    1141         )
#    1142     q = self._query_class(
#    1143         self.__query_flags,
#    1144         self.__collection.database.name,
#    (...)
#    1158         self.__exhaust,
#    1159     )
# -> 1160     self.__send_message(q)
#    1161 elif self.__id:  # Get More
#    1162     if self.__limit:
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/cursor.py:1039, in Cursor.__send_message(self, operation)
#    1036     raise InvalidOperation("exhaust cursors do not support auto encryption")
#    1038 try:
# -> 1039     response = client._run_operation(
#    1040         operation, self._unpack_response, address=self.__address
#    1041     )
#    1042 except OperationFailure as exc:
#    1043     if exc.code in _CURSOR_CLOSED_ERRORS or self.__exhaust:
#    1044         # Don't send killCursors because the cursor is already closed.
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/mongo_client.py:1425, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1415     operation.reset()  # Reset op in case of retry.
#    1416     return server.run_operation(
#    1417         conn,
#    1418         operation,
#    (...)
#    1422         self,
#    1423     )
# -> 1425 return self._retryable_read(
#    1426     _cmd,
#    1427     operation.read_preference,
#    1428     operation.session,
#    1429     address=address,
#    1430     retryable=isinstance(operation, message._Query),
#    1431     operation=operation.name,
#    1432 )
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/mongo_client.py:1534, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    1529 # Ensure that the client supports retrying on reads and there is no session in
#    1530 # transaction, otherwise, we will not support retry behavior for this call.
#    1531 retryable = bool(
#    1532     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    1533 )
# -> 1534 return self._retry_internal(
#    1535     func,
#    1536     session,
#    1537     None,
#    1538     operation,
#    1539     is_read=True,
#    1540     address=address,
#    1541     read_pref=read_pref,
#    1542     retryable=retryable,
#    1543     operation_id=operation_id,
#    1544 )
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/mongo_client.py:1501, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1464 @_csot.apply
#    1465 def _retry_internal(
#    1466     self,
#    (...)
#    1475     operation_id: Optional[int] = None,
#    1476 ) -> T:
#    1477     """Internal retryable helper for all client transactions.
#    1478
#    1479     :param func: Callback function we want to retry
#    (...)
#    1488     :return: Output of the calling func()
#    1489     """
#    1490     return _ClientConnectionRetryable(
#    1491         mongo_client=self,
#    1492         func=func,
#    1493         bulk=bulk,
#    1494         operation=operation,
#    1495         is_read=is_read,
#    1496         session=session,
#    1497         read_pref=read_pref,
#    1498         address=address,
#    1499         retryable=retryable,
#    1500         operation_id=operation_id,
# -> 1501     ).run()
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/mongo_client.py:2347, in _ClientConnectionRetryable.run(self)
#    2345 self._check_last_error(check_csot=True)
#    2346 try:
# -> 2347     return self._read() if self._is_read else self._write()
#    2348 except ServerSelectionTimeoutError:
#    2349     # The application may think the write was never attempted
#    2350     # if we raise ServerSelectionTimeoutError on the retry
#    2351     # attempt. Raise the original exception instead.
#    2352     self._check_last_error()
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/mongo_client.py:2477, in _ClientConnectionRetryable._read(self)
#    2472 def _read(self) -> T:
#    2473     """Wrapper method for read-type retryable client executions
#    2474
#    2475     :return: Output for func()'s call
#    2476     """
# -> 2477     self._server = self._get_server()
#    2478     assert self._read_pref is not None, "Read Preference required on read calls"
#    2479     with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2480         conn,
#    2481         read_pref,
#    2482     ):
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/mongo_client.py:2433, in _ClientConnectionRetryable._get_server(self)
#    2428 def _get_server(self) -> Server:
#    2429     """Retrieves a server object based on provided object context
#    2430
#    2431     :return: Abstraction to connect to server
#    2432     """
# -> 2433     return self._client._select_server(
#    2434         self._server_selector,
#    2435         self._session,
#    2436         self._operation,
#    2437         address=self._address,
#    2438         deprioritized_servers=self._deprioritized_servers,
#    2439         operation_id=self._operation_id,
#    2440     )
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/mongo_client.py:1316, in MongoClient._select_server(self, server_selector, session, operation, address, deprioritized_servers, operation_id)
#    1314             raise AutoReconnect("server %s:%s no longer available" % address)  # noqa: UP031
#    1315     else:
# -> 1316         server = topology.select_server(
#    1317             server_selector,
#    1318             operation,
#    1319             deprioritized_servers=deprioritized_servers,
#    1320             operation_id=operation_id,
#    1321         )
#    1322     return server
#    1323 except PyMongoError as exc:
#    1324     # Server selection errors in a transaction are transient.
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/topology.py:369, in Topology.select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     359 def select_server(
#     360     self,
#     361     selector: Callable[[Selection], Selection],
#    (...)
#     366     operation_id: Optional[int] = None,
#     367 ) -> Server:
#     368     """Like select_servers, but choose a random server if several match."""
# --> 369     server = self._select_server(
#     370         selector,
#     371         operation,
#     372         server_selection_timeout,
#     373         address,
#     374         deprioritized_servers,
#     375         operation_id=operation_id,
#     376     )
#     377     if _csot.get_timeout():
#     378         _csot.set_rtt(server.description.min_round_trip_time)
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/topology.py:347, in Topology._select_server(self, selector, operation, server_selection_timeout, address, deprioritized_servers, operation_id)
#     338 def _select_server(
#     339     self,
#     340     selector: Callable[[Selection], Selection],
#    (...)
#     345     operation_id: Optional[int] = None,
#     346 ) -> Server:
# --> 347     servers = self.select_servers(
#     348         selector, operation, server_selection_timeout, address, operation_id
#     349     )
#     350     servers = _filter_servers(servers, deprioritized_servers)
#     351     if len(servers) == 1:
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/topology.py:254, in Topology.select_servers(self, selector, operation, server_selection_timeout, address, operation_id)
#     251     server_timeout = server_selection_timeout
#     253 with self._lock:
# --> 254     server_descriptions = self._select_servers_loop(
#     255         selector, server_timeout, operation, operation_id, address
#     256     )
#     258     return [
#     259         cast(Server, self.get_server_by_address(sd.address)) for sd in server_descriptions
#     260     ]
#
# File /opt/jupyter-venv/lib/python3.12/site-packages/pymongo/topology.py:304, in Topology._select_servers_loop(self, selector, timeout, operation, operation_id, address)
#     293     if _SERVER_SELECTION_LOGGER.isEnabledFor(logging.DEBUG):
#     294         _debug_log(
#     295             _SERVER_SELECTION_LOGGER,
#     296             message=_ServerSelectionStatusMessage.FAILED,
#    (...)
#     302             failure=self._error_message(selector),
#     303         )
# --> 304     raise ServerSelectionTimeoutError(
#     305         f"{self._error_message(selector)}, Timeout: {timeout}s, Topology Description: {self.description!r}"
#     306     )
#     308 if not logged_waiting:
#     309     _info_log(
#     310         _SERVER_SELECTION_LOGGER,
#     311         message=_ServerSelectionStatusMessage.WAITING,
#    (...)
#     317         remainingTimeMS=int(end_time - time.monotonic()),
#     318     )
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 6644e656549f0ccf9f7938f6, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
